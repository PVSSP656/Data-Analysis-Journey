# %%
import pandas as pd

# %%
data_one = {'A': ['A0', 'A1', 'A2', 'A3'],'B': ['B0', 'B1', 'B2', 'B3']}

# %%
data_two = {'C': ['C0', 'C1', 'C2', 'C3'], 'D': ['D0', 'D1', 'D2', 'D3']}

# %%
one = pd.DataFrame(data_one)

# %%
two = pd.DataFrame(data_two)

# %%
one
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3

# %%
two
# Out:
#     C   D
# 0  C0  D0
# 1  C1  D1
# 2  C2  D2
# 3  C3  D3

# %% [markdown]
# Let's get a single dataframe with 4 columns (since the index is same):

# %%
pd.concat([one,two],axis=1)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
pd.concat([two,one],axis=1)
# Out:
#     C   D   A   B
# 0  C0  D0  A0  B0
# 1  C1  D1  A1  B1
# 2  C2  D2  A2  B2
# 3  C3  D3  A3  B3

# %%
df = pd.concat([one,two],axis=0)

# %%
df.fillna('-')
# Out:
#     A   B   C   D
# 0  A0  B0   -   -
# 1  A1  B1   -   -
# 2  A2  B2   -   -
# 3  A3  B3   -   -
# 0   -   -  C0  D0
# 1   -   -  C1  D1
# 2   -   -  C2  D2
# 3   -   -  C3  D3

# %% [markdown]
# Not in lecture, but let's try giving index to the above df

# %%
df.index = range(0,8)

# %%
df
# Out:
#      A    B    C    D
# 0   A0   B0  NaN  NaN
# 1   A1   B1  NaN  NaN
# 2   A2   B2  NaN  NaN
# 3   A3   B3  NaN  NaN
# 4  NaN  NaN   C0   D0
# 5  NaN  NaN   C1   D1
# 6  NaN  NaN   C2   D2
# 7  NaN  NaN   C3   D3

# %% [markdown]
# Let's try giving the index, but not manually

# %%
len(df)
# Out:
# 8

# %%
df.index = range(0,len(df))

# %%
df
# Out:
#      A    B    C    D
# 0   A0   B0  NaN  NaN
# 1   A1   B1  NaN  NaN
# 2   A2   B2  NaN  NaN
# 3   A3   B3  NaN  NaN
# 4  NaN  NaN   C0   D0
# 5  NaN  NaN   C1   D1
# 6  NaN  NaN   C2   D2
# 7  NaN  NaN   C3   D3

# %% [markdown]
# If we want the index to start from 1 instead of zero:

# %%
df.index = range(1,len(df)+1)

# %%
df
# Out:
#      A    B    C    D
# 1   A0   B0  NaN  NaN
# 2   A1   B1  NaN  NaN
# 3   A2   B2  NaN  NaN
# 4   A3   B3  NaN  NaN
# 5  NaN  NaN   C0   D0
# 6  NaN  NaN   C1   D1
# 7  NaN  NaN   C2   D2
# 8  NaN  NaN   C3   D3

# %% [markdown]
# ### Instead of getting NaN, let's try shifting C0,C1... and D0,D1... below A and B:

# %%
one
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3

# %%
two
# Out:
#     C   D
# 0  C0  D0
# 1  C1  D1
# 2  C2  D2
# 3  C3  D3

# %%
two.columns = one.columns

# %%
two
# Out:
#     A   B
# 0  C0  D0
# 1  C1  D1
# 2  C2  D2
# 3  C3  D3

# %% [markdown]
# What we did as changed the column of 'two' to be same as that of 'one'

# %% [markdown]
# Now, since the column names match up, we can proceed:

# %%
df = pd.concat([one,two],axis=0)

# %%
df
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 0  C0  D0
# 1  C1  D1
# 2  C2  D2
# 3  C3  D3
